# %% [markdown]
# # dtale for EDA and Visualization

# %%
# import libraries
import pandas as pd
import seaborn as sns
import dtale

# %%
# load data
df = sns.load_dataset('tips')
# start dtale server
d = dtale.show(df)

# %%
# open browser
d.open_browser()

# %%
# close dtale server
d.kill()
# Out:
# 2026-01-16 10:35:48,032 - INFO     - Executing shutdown...
# 2026-01-16 10:35:48,032 - INFO     - Not running with the Werkzeug Server, exiting by searching gc for BaseWSGIServer
