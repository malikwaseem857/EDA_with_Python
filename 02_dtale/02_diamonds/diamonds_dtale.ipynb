# %%
# import libraries
import pandas as pd
import seaborn as sns
import dtale

# %%
# load data
df = sns.load_dataset('diamonds')
# start dtale server
d = dtale.show(df)
d.open_browser()
# Out:
# 2026-01-16 10:41:25,722 - ERROR    - Exception occurred while processing request: Could not convert value of 'y' into a numeric type.
# Traceback (most recent call last):
#   File "c:\Users\USER\miniconda3\envs\dtale\Lib\site-packages\plotly\express\_core.py", line 404, in make_trace_kwargs
#     y = y.cast(nw.Float64())
#         ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USER\miniconda3\envs\dtale\Lib\site-packages\narwhals\series.py", line 627, in cast
#     return self._with_compliant(self._compliant_series.cast(dtype))
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USER\miniconda3\envs\dtale\Lib\site-packages\narwhals\_pandas_like\series.py", line 321, in cast
#     return self._with_native(self.native.astype(pd_dtype), preserve_broadcast=True)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USER\miniconda3\envs\dtale\Lib\site-packages\pandas\core\generic.py", line 6665, in astype
# ...

# %%
# kill the server when done
d.kill()
# Out:
# 2026-01-16 10:37:49,957 - INFO     - Executing shutdown...
# 2026-01-16 10:37:49,957 - INFO     - Not running with the Werkzeug Server, exiting by searching gc for BaseWSGIServer
