# %%
# import libraries
import pandas as pd
import seaborn as sns
import dtale

# %%
# load data
df = sns.load_dataset('diamonds')
# start dtale server
d = dtale.show(df)
d.open_browser()

# %%
# kill the server when done
d.kill()
# Out:
# 2026-01-13 15:00:54,811 - INFO     - Executing shutdown...
# 2026-01-13 15:00:54,811 - INFO     - Not running with the Werkzeug Server, exiting by searching gc for BaseWSGIServer
