# %% [markdown]
# # Pandas AI usage example

# %%
import pandasai as pai
from pandasai_litellm.litellm import LiteLLM

# %%
# Initialize LiteLLM with your OpenAI model
llm = LiteLLM(model="gpt-4.1-mini", api_key="YOUR_OPENAI_API_KEY")

# Configure PandasAI to use this LLM
pai.config.set({
    "llm": llm
})

# %%
# Load your data
df = pai.read_csv("iran_gdp.csv")

# %%
response = df.chat("When was the highest GDP_Growth_Percent?")
print(response)
# Out:
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# File c:\Users\USER\miniconda3\envs\pandas_ai\lib\site-packages\litellm\llms\openai\openai.py:762, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, api_version, dynamic_params, azure_ad_token, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params, shared_session)
#     761             else:
# --> 762                 raise e
#     763 except OpenAIError as e:
#
# File c:\Users\USER\miniconda3\envs\pandas_ai\lib\site-packages\litellm\llms\openai\openai.py:690, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, api_version, dynamic_params, azure_ad_token, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params, shared_session)
#     676 logging_obj.pre_call(
#     677     input=messages,
#     678     api_key=openai_client.api_key,
#    (...)
#     684     },
#     685 )
#     687 (
#     688     headers,
#     689     response,
# --> 690 ) = self.make_sync_openai_chat_completion_request(
#     691     openai_client=openai_client,
#     692     data=data,
#     693     timeout=timeout,
#     694     logging_obj=logging_obj,
#     695 )
#     697 logging_obj.model_call_details["response_headers"] = headers
#
# File c:\Users\USER\miniconda3\envs\pandas_ai\lib\site-packages\litellm\litellm_core_utils\logging_utils.py:237, in track_llm_api_timing.<locals>.decorator.<locals>.sync_wrapper(*args, **kwargs)
#     236 try:
# --> 237     result = func(*args, **kwargs)
#     238     return result
#
# File c:\Users\USER\miniconda3\envs\pandas_ai\lib\site-packages\litellm\llms\openai\openai.py:502, in OpenAIChatCompletion.make_sync_openai_chat_completion_request(self, openai_client, data, timeout, logging_obj)
#     501 else:
# --> 502     raise e
#
# File c:\Users\USER\miniconda3\envs\pandas_ai\lib\site-packages\litellm\llms\openai\openai.py:477, in OpenAIChatCompletion.make_sync_openai_chat_completion_request(self, openai_client, data, timeout, logging_obj)
#     476 try:
# --> 477     raw_response = openai_client.chat.completions.with_raw_response.create(
#     478         **data, timeout=timeout
#     479     )
#     481     if hasattr(raw_response, "headers"):
#
# File c:\Users\USER\miniconda3\envs\pandas_ai\lib\site-packages\openai\_legacy_response.py:364, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     362 kwargs["extra_headers"] = extra_headers
# --> 364 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File c:\Users\USER\miniconda3\envs\pandas_ai\lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File c:\Users\USER\miniconda3\envs\pandas_ai\lib\site-packages\openai\resources\chat\completions\completions.py:1192, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1191 validate_response_format(response_format)
# -> 1192 return self._post(
#    1193     "/chat/completions",
#    1194     body=maybe_transform(
#    1195         {
#    1196             "messages": messages,
#    1197             "model": model,
#    1198             "audio": audio,
#    1199             "frequency_penalty": frequency_penalty,
#    1200             "function_call": function_call,
#    1201             "functions": functions,
#    1202             "logit_bias": logit_bias,
#    1203             "logprobs": logprobs,
#    1204             "max_completion_tokens": max_completion_tokens,
#    1205             "max_tokens": max_tokens,
#    1206             "metadata": metadata,
#    1207             "modalities": modalities,
#    1208             "n": n,
#    1209             "parallel_tool_calls": parallel_tool_calls,
#    1210             "prediction": prediction,
#    1211             "presence_penalty": presence_penalty,
#    1212             "prompt_cache_key": prompt_cache_key,
#    1213             "prompt_cache_retention": prompt_cache_retention,
#    1214             "reasoning_effort": reasoning_effort,
#    1215             "response_format": response_format,
#    1216             "safety_identifier": safety_identifier,
#    1217             "seed": seed,
#    1218             "service_tier": service_tier,
#    1219             "stop": stop,
#    1220             "store": store,
#    1221             "stream": stream,
#    1222             "stream_options": stream_options,
#    1223             "temperature": temperature,
#    1224             "tool_choice": tool_choice,
#    1225             "tools": tools,
#    1226             "top_logprobs": top_logprobs,
#    1227             "top_p": top_p,
#    1228             "user": user,
#    1229             "verbosity": verbosity,
#    1230             "web_search_options": web_search_options,
#    1231         },
#    1232         completion_create_params.CompletionCreateParamsStreaming
#    1233         if stream
#    1234         else completion_create_params.CompletionCreateParamsNonStreaming,
#    1235     ),
#    1236     options=make_request_options(
#    1237         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1238     ),
#    1239     cast_to=ChatCompletion,
#    1240     stream=stream or False,
#    1241     stream_cls=Stream[ChatCompletionChunk],
#    1242 )
#
# File c:\Users\USER\miniconda3\envs\pandas_ai\lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1256 opts = FinalRequestOptions.construct(
#    1257     method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258 )
# -> 1259 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\USER\miniconda3\envs\pandas_ai\lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1046     log.debug("Re-raising status error")
# -> 1047     raise self._make_status_error_from_response(err.response) from None
#    1049 break
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: YOUR_OPE*******_KEY. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
#
# During handling of the above exception, another exception occurred:
#
# OpenAIError                               Traceback (most recent call last)
# File c:\Users\USER\miniconda3\envs\pandas_ai\lib\site-packages\litellm\main.py:2448, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, verbosity, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    2442     logging.post_call(
#    2443         input=messages,
#    2444         api_key=api_key,
#    2445         original_response=str(e),
#    2446         additional_args={"headers": headers},
#    2447     )
# -> 2448     raise e
#    2450 if optional_params.get("stream", False):
#    2451     ## LOGGING
#
# File c:\Users\USER\miniconda3\envs\pandas_ai\lib\site-packages\litellm\main.py:2420, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, verbosity, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    2419     else:
# -> 2420         response = openai_chat_completions.completion(
#    2421             model=model,
#    2422             messages=messages,
#    2423             headers=headers,
#    2424             model_response=model_response,
#    2425             print_verbose=print_verbose,
#    2426             api_key=api_key,
#    2427             api_base=api_base,
#    2428             acompletion=acompletion,
#    2429             logging_obj=logging,
#    2430             optional_params=optional_params,
#    2431             litellm_params=litellm_params,
#    2432             logger_fn=logger_fn,
#    2433             timeout=timeout,  # type: ignore
#    2434             custom_prompt_dict=custom_prompt_dict,
#    2435             client=client,  # pass AsyncOpenAI, OpenAI client
#    2436             organization=organization,
#    2437             custom_llm_provider=custom_llm_provider,
#    2438             shared_session=shared_session,
#    2439         )
#    2440 except Exception as e:
#    2441     ## LOGGING - log the original exception returned
#
# File c:\Users\USER\miniconda3\envs\pandas_ai\lib\site-packages\litellm\llms\openai\openai.py:773, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, api_version, dynamic_params, azure_ad_token, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params, shared_session)
#     772     error_headers = getattr(error_response, "headers", None)
# --> 773 raise OpenAIError(
#     774     status_code=status_code,
#     775     message=error_text,
#     776     headers=error_headers,
#     777     body=error_body,
#     778 )
#
# OpenAIError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: YOUR_OPE*******_KEY. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
#
# During handling of the above exception, another exception occurred:
#
# AuthenticationError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 response = df.chat("When was the highest GDP_Growth_Percent?")
#       2 print(response)
#
# File c:\Users\USER\miniconda3\envs\pandas_ai\lib\site-packages\pandasai\dataframe\base.py:118, in DataFrame.chat(self, prompt, sandbox)
#     112     from pandasai.agent import (
#     113         Agent,
#     114     )
#     116     self._agent = Agent([self], sandbox=sandbox)
# --> 118 return self._agent.chat(prompt)
#
# File c:\Users\USER\miniconda3\envs\pandas_ai\lib\site-packages\pandasai\agent\base.py:103, in Agent.chat(self, query, output_type)
#      97     raise ValueError(
#      98         "PandasAI API key does not include LLM credits. Please configure an OpenAI or LiteLLM key. "
#      99         "Learn more at: https://docs.pandas-ai.com/v3/large-language-models#how-to-set-up-any-llm%3F"
#     100     )
#     102 self.start_new_conversation()
# --> 103 return self._process_query(query, output_type)
#
# File c:\Users\USER\miniconda3\envs\pandas_ai\lib\site-packages\pandasai\agent\base.py:284, in Agent._process_query(self, query, output_type)
#     281 self._state.assign_prompt_id()
#     283 # Generate code
# --> 284 code = self.generate_code_with_retries(str(query))
#     286 # Execute code with retries
#     287 result = self.execute_with_retries(code)
#
# File c:\Users\USER\miniconda3\envs\pandas_ai\lib\site-packages\pandasai\agent\base.py:181, in Agent.generate_code_with_retries(self, query)
#     179 while attempts <= max_retries:
#     180     try:
# --> 181         return self._regenerate_code_after_error(
#     182             self._state.last_code_generated, exception
#     183         )
#     184     except Exception as e:
#     185         exception = e
#
# File c:\Users\USER\miniconda3\envs\pandas_ai\lib\site-packages\pandasai\agent\base.py:308, in Agent._regenerate_code_after_error(self, code, error)
#     305 else:
#     306     prompt = get_correct_error_prompt_for_sql(self._state, code, error_trace)
# --> 308 return self._code_generator.generate_code(prompt)
#
# File c:\Users\USER\miniconda3\envs\pandas_ai\lib\site-packages\pandasai\core\code_generation\base.py:52, in CodeGenerator.generate_code(self, prompt)
#      49 self._context.logger.log(error_message)
#      50 self._context.logger.log(f"Stack Trace:\n{stack_trace}")
# ---> 52 raise e
#
# File c:\Users\USER\miniconda3\envs\pandas_ai\lib\site-packages\pandasai\core\code_generation\base.py:33, in CodeGenerator.generate_code(self, prompt)
#      30 self._context.logger.log(f"Using Prompt: {prompt}")
#      32 # Generate the code
# ---> 33 code = self._context.config.llm.generate_code(prompt, self._context)
#      34 # Store the original generated code (for logging purposes)
#      35 self._context.last_code_generated = code
#
# File c:\Users\USER\miniconda3\envs\pandas_ai\lib\site-packages\pandasai\llm\base.py:173, in LLM.generate_code(self, instruction, context)
#     161 def generate_code(self, instruction: BasePrompt, context: AgentState) -> str:
#     162     """
#     163     Generate the code based on the instruction and the given prompt.
#     164
#    (...)
#     171
#     172     """
# --> 173     response = self.call(instruction, context)
#     174     return self._extract_code(response)
#
# File c:\Users\USER\miniconda3\envs\pandas_ai\lib\site-packages\pandasai_litellm\litellm.py:68, in LiteLLM.call(self, instruction, _)
#      52 """Generates a completion response based on the provided instruction.
#      53
#      54 This method converts the given instruction into a user prompt string and
#    (...)
#      62 Returns:
#      63     str: The content of the model's response to the user prompt."""
#      65 user_prompt = instruction.to_string()
#      67 return (
# ---> 68     completion(
#      69         model=self.model,
#      70         messages=[{"content": user_prompt, "role": "user"}],
#      71         **self.params,
#      72     )
#      73     .choices[0]
#      74     .message.content
#      75 )
#
# File c:\Users\USER\miniconda3\envs\pandas_ai\lib\site-packages\litellm\utils.py:1651, in client.<locals>.wrapper(*args, **kwargs)
#    1647 if logging_obj:
#    1648     logging_obj.failure_handler(
#    1649         e, traceback_exception, start_time, end_time
#    1650     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1651 raise e
#
# File c:\Users\USER\miniconda3\envs\pandas_ai\lib\site-packages\litellm\utils.py:1515, in client.<locals>.wrapper(*args, **kwargs)
#    1513         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1514 # MODEL CALL
# -> 1515 result = original_function(*args, **kwargs)
#    1516 end_time = datetime.datetime.now()
#    1517 if _is_streaming_request(
#    1518     kwargs=kwargs,
#    1519     call_type=call_type,
#    1520 ):
#
# File c:\Users\USER\miniconda3\envs\pandas_ai\lib\site-packages\litellm\main.py:4159, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, verbosity, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    4156     return response
#    4157 except Exception as e:
#    4158     ## Map to OpenAI Exception
# -> 4159     raise exception_type(
#    4160         model=model,
#    4161         custom_llm_provider=custom_llm_provider,
#    4162         original_exception=e,
#    4163         completion_kwargs=args,
#    4164         extra_kwargs=kwargs,
#    4165     )
#
# File c:\Users\USER\miniconda3\envs\pandas_ai\lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2346, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2344 if exception_mapping_worked:
#    2345     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2346     raise e
#    2347 else:
#    2348     for error_type in litellm.LITELLM_EXCEPTION_TYPES:
#
# File c:\Users\USER\miniconda3\envs\pandas_ai\lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:492, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#     490 elif original_exception.status_code == 401:
#     491     exception_mapping_worked = True
# --> 492     raise AuthenticationError(
#     493         message=f"AuthenticationError: {exception_provider} - {message}",
#     494         llm_provider=custom_llm_provider,
#     495         model=model,
#     496         response=getattr(original_exception, "response", None),
#     497         litellm_debug_info=extra_information,
#     498     )
#     499 elif original_exception.status_code == 404:
#     500     exception_mapping_worked = True
#
# AuthenticationError: litellm.AuthenticationError: AuthenticationError: OpenAIException - Incorrect API key provided: YOUR_OPE*******_KEY. You can find your API key at https://platform.openai.com/account/api-keys.
