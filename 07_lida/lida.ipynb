# %%
from lida import Manager, llm

# %%
from lida import Manager, llm

lida = Manager(text_gen = llm("openai")) # palm, cohere ..
summary = lida.summarize("iran_gdp.csv")
goals = lida.goals(summary, n=2) # exploratory data analysis
charts = lida.visualize(summary=summary, goal=goals[0]) # exploratory data analysis
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 from lida import Manager, llm
# ----> 3 lida = Manager(text_gen = llm("openai")) # palm, cohere ..
#       4 summary = lida.summarize("iran_gdp.csv")
#       5 goals = lida.goals(summary, n=2) # exploratory data analysis
#
# File c:\Users\USER\miniconda3\envs\lida\lib\site-packages\llmx\generators\text\textgen.py:52, in llm(provider, **kwargs)
#      49 # print(kwargs)
#      51 if provider.lower() == "openai":
# ---> 52     return OpenAITextGenerator(**kwargs)
#      53 elif provider.lower() == "palm":
#      54     return PalmTextGenerator(**kwargs)
#
# File c:\Users\USER\miniconda3\envs\lida\lib\site-packages\llmx\generators\text\openai_textgen.py:26, in OpenAITextGenerator.__init__(self, api_key, provider, organization, api_type, api_version, azure_endpoint, model, models)
#      23 self.api_key = api_key or os.environ.get("OPENAI_API_KEY", None)
#      25 if self.api_key is None:
# ---> 26     raise ValueError(
#      27         "OpenAI API key is not set. Please set the OPENAI_API_KEY environment variable."
#      28     )
#      30 self.client_args = {
#      31     "api_key": self.api_key,
#      32     "organization": organization,
#      33     "api_version": api_version,
#      34     "azure_endpoint": azure_endpoint,
#      35 }
#      36 # remove keys with None values
#
# ValueError: OpenAI API key is not set. Please set the OPENAI_API_KEY environment variable.
