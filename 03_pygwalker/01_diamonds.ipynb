# %%
import pandas as pd
import pygwalker as pyg
import seaborn as sns

# %%
df = sns.load_dataset("diamonds")
walker = pyg.walk(df)
# Out:
# Box(children=(HTML(value='\n<div id="ifr-pyg-0006487b5fa03c34LCIFvO2a0jNKftEU" style="height: auto">\n    <hea…
# <script>
#     window.addEventListener("message", function(event) {
#         const backgroundMap = {
#             "dark": "hsl(240 10% 3.9%)",
#             "light": "hsl(0 0 100%)",
#         };
#         const colorMap = {
#             "dark": "hsl(0 0% 98%)",
#             "light": "hsl(240 10% 3.9%)",
#         };
#         if (event.data.action === "changeAppearance" && event.data.gid === "0006487b5fa03c34LCIFvO2a0jNKftEU") {
#             var iframe = document.getElementById("gwalker-0006487b5fa03c34LCIFvO2a0jNKftEU");
#             iframe.style.background  = backgroundMap[event.data.appearance];
#             iframe.style.color = colorMap[event.data.appearance];
#         }
#     });
# </script>
