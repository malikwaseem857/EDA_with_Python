# %% [markdown]
# # EDA with Pandas Profiling

# %%
# step 1: Impoprt necessary libraries
import pandas as pd
import seaborn as sns
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv("pop_and_net_migration.csv")

# %%
# Step 2: load dataset
df = pd.read_csv("pop_and_net_migration.csv")

# %%
# Step 3:run pandas profiling and save into html file
profile = ProfileReport(df, title="Profiling Report")
profile.to_file("net_migration_profiling_report.html")
# Out:
# 100%|██████████| 4/4 [00:00<?, ?it/s]/9 [00:00<00:00, 12.48it/s, Describe variable: net_migration]
# Summarize dataset: 100%|██████████| 22/22 [00:02<00:00,  9.19it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:02<00:00,  2.33s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.02it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 109.28it/s]
