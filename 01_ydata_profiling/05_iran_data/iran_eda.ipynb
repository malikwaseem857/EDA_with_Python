# %%
# step 1: Impoprt necessary libraries
import pandas as pd
import seaborn as sns
from ydata_profiling import ProfileReport
# Step 2: load dataset
df = pd.read_csv("iran_gdp.csv")
# Step 3:run pandas profiling and save into html file
profile = ProfileReport(df, title="Profiling Report")
profile.to_file("iran_gdp_profiling_report.html")
# Out:
# 100%|██████████| 13/13 [00:00<00:00, 468.63it/s]<00:00, 40.63it/s, Describe variable: Industry_Value_Added_Percent_GDP]
# Summarize dataset: 100%|██████████| 192/192 [00:31<00:00,  6.18it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:08<00:00,  8.15s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  1.17it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 33.16it/s]
