# %%
import pandas as pd
from dataprep.eda import create_report

# %%
df = pd.read_csv("iran_gdp.csv")
report = create_report(df)
report.save("iran_gdp_report.html")
# Out:
#   0%|          | 0/2647 [00:00<?, ?it/s]
# c:\Users\codanics.TUFAIL\miniconda3\envs\dataprep\lib\site-packages\dask\core.py:127: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# Report has been saved to iran_gdp_report.html!

# %%
report.show_browser()
